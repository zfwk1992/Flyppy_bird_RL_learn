# %% [markdown]
# # 查看对抗学习理论分析文档
#
# 运行下面的代码来查看完整的理论分析文档：

# %%
from IPython.display import Markdown, display

# 读取并显示Markdown文档
with open('Adversarial_Learning_Theory_Analysis.md', 'r', encoding='utf-8') as f:
    content = f.read()

display(Markdown(content))
